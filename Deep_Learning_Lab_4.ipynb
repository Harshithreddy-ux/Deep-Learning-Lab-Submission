# %% [markdown]
# # DEPARTMENT OF COMPUTER SCIENCE AND ENGINEERING (AI)
#
# # DEEP LEARNING LAB RECORD
#
# ---
#
# # LAB - 04
#
# ## Student Details
#
# **Name:** P. Harshith
#
# **Register Number:** CH.SC.U4AIE24057
#
# **Course Name:** Deep Learning
#
# **Course Code:** 22AIE304
#
# ---
#
# # Experiment Title
#
# **Deep Neural Network (DNN) for Handwritten Digit Classification using the MNIST Dataset**
#
# ---
#
# ## Aim
#
# To build and train a Deep Neural Network (DNN) using TensorFlow/Keras for handwritten digit classification on the MNIST dataset.
#
# ---
#
# ## Objective
#
# - Load the MNIST dataset.
# - Preprocess image data.
# - Build a Deep Neural Network.
# - Train the model.
# - Evaluate its performance.
# - Predict handwritten digits.
#
# ---
#
# ## Dataset
#
# **Dataset Name:** MNIST Handwritten Digits
#
# **Training Images:** 60,000
#
# **Testing Images:** 10,000
#
# **Image Size:** 28 × 28 pixels
#
# **Classes:** 0–9
#
# ---
#
# ## Software Requirements
#
# - Python 3.x
# - TensorFlow
# - NumPy
# - Matplotlib
# - Scikit-Learn
# - Jupyter Notebook
#
# ---
#
# ## Required Libraries
#
# - tensorflow
# - numpy
# - matplotlib

# %%
# !pip install tensorflow matplotlib numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow matplotlib numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
# Load MNIST Dataset

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(X_train.shape)
print(X_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %%
# Display Sample Images

plt.figure(figsize=(10,5))

for i in range(10):

    plt.subplot(2,5,i+1)

    plt.imshow(X_train[i], cmap="gray")

    plt.title(y_train[i])

    plt.axis("off")

plt.show()

# %%
# Normalize Images

X_train = X_train / 255.0

X_test = X_test / 255.0

# %%
# Build Deep Neural Network

model = Sequential()

model.add(Flatten(input_shape=(28,28)))

model.add(Dense(128, activation='relu'))

model.add(Dense(64, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# c:\Users\msi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ...

# %%
# Compile Model

model.compile(

    optimizer='adam',

    loss='sparse_categorical_crossentropy',

    metrics=['accuracy']

)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# Train Model

history = model.fit(

    X_train,

    y_train,

    epochs=10,

    batch_size=32,

    validation_split=0.2

)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9221 - loss: 0.2693 - val_accuracy: 0.9515 - val_loss: 0.1580
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9646 - loss: 0.1172 - val_accuracy: 0.9584 - val_loss: 0.1352
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9753 - loss: 0.0799 - val_accuracy: 0.9715 - val_loss: 0.0973
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9805 - loss: 0.0603 - val_accuracy: 0.9693 - val_loss: 0.1054
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9852 - loss: 0.0467 - val_accuracy: 0.9739 - val_loss: 0.0912
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9886 - loss: 0.0359 - val_accuracy: 0.9718 - val_loss: 0.1061
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9904 - loss: 0.0297 - val_accuracy: 0.9708 - val_loss: 0.1027
# Epoch 8/10
# ...

# %%
# Evaluate Model

loss, accuracy = model.evaluate(X_test, y_test)

print("Test Loss :", loss)

print("Test Accuracy :", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.9799 - loss: 0.0932
# Test Loss : 0.0931696817278862
# Test Accuracy : 0.9799000024795532

# %%
# Predict Digits

predictions = model.predict(X_test)

predicted_labels = np.argmax(predictions, axis=1)

print(predicted_labels[:10])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# [7 2 1 0 4 1 4 9 5 9]

# %%
# Compare Actual and Predicted

for i in range(5):

    plt.figure(figsize=(2,2))

    plt.imshow(X_test[i], cmap='gray')

    plt.title(f"Actual : {y_test[i]}  Predicted : {predicted_labels[i]}")

    plt.axis('off')

    plt.show()

# %%
# Plot Accuracy

plt.plot(history.history['accuracy'])

plt.plot(history.history['val_accuracy'])

plt.title("Training and Validation Accuracy")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")

plt.legend(["Training","Validation"])

plt.show()

# %%
# Plot Loss

plt.plot(history.history['loss'])

plt.plot(history.history['val_loss'])

plt.title("Training and Validation Loss")

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.legend(["Training","Validation"])

plt.show()

# %%
# Classification Report

from sklearn.metrics import classification_report

print(classification_report(y_test, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.99      0.96      0.97      1032
#            3       0.97      0.99      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.99      0.98      0.98       892
#            6       0.99      0.98      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.97      0.98      0.97       974
#            9       0.98      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
# Confusion Matrix

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predicted_labels)

print(cm)
# Out:
# [[ 974    0    0    0    0    1    2    1    2    0]
#  [   0 1125    3    2    0    0    0    2    2    1]
#  [   7    0  993    7    4    0    5    9    7    0]
#  [   1    0    1  998    0    2    0    3    4    1]
#  [   2    0    3    1  965    0    2    1    2    6]
#  [   2    0    0    8    1  870    2    1    5    3]
#  [   7    4    0    1    2    3  940    0    1    0]
#  [   1    4    3    2    0    0    1 1008    2    7]
#  [   3    0    3    5    2    2    1    3  951    4]
#  [   2    2    0    9   10    4    0    5    2  975]]
